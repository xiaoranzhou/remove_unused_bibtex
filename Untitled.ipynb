# %%
bib_file = "these.bib"
bbl_file = "output.bbl"
aux_file = "output.aux"

# %%
def remove_unused_references(bib_file, bbl_file, aux_file):
    used_references = set()

    with open(bbl_file, "r") as bbl:
        for line in bbl:
            if line.startswith("\entry{"):
                reference = line.strip().split("{")[1][:-1]
                used_references.add(reference)
                print(reference)

    with open(aux_file, "r") as aux:
        for line in aux:
            if line.startswith("\\abx@aux@cite{0}{"):
                reference = line.strip().split("{")[2][:-1]
                used_references.add(reference)

    with open(bib_file, "r") as bib:
        bib_lines = bib.readlines()

    with open(bib_file, "w") as bib:
        in_reference = False
        reference_name = ""

        for line in bib_lines:
            if line.startswith("@"):
                reference_name = line.strip().split("{")[1].split(",")[0]
                in_reference = reference_name in used_references
                if in_reference:
                    bib.write(line)
            elif in_reference:
                bib.write(line)



remove_unused_references(bib_file, bbl_file, aux_file)

# %%
with open(bbl_file, "r") as bbl:
    for line in bbl:
        if line.startswith("\entry{"):
            reference = line.strip().split("{")[1][:-1]
            used_references.add(reference)
            print(reference)

# %%
used_references = set()
with open(bbl_file, "r") as bbl:
    for line in bbl:
        if line.startswith("    \entry{"):
            reference = line.strip().split("{")[1][:-1]
            used_references.add(reference)
            print(reference)
# Out:
# Ahmed2022-te
# Almeida2007-jx
# Bar-On2018-ul
# Barczi2008-gv
# Beer2010-uj
# Bidel2000-nf
# Boardman1977-ai
# Cabon2020-vg
# Clerx2020-ft
# Colombie2005-bo
# Comtet2017-ou
# Comtet2017-bj
# Cosgrove2005-rv
# Coussement2018-py
# Da_Silva2014-rb
# Daudet2005-eu
# De_Bauw2020-th
# De_Swaef2015-wc
# Delory2016-gb
# Dilkes2004-zi
# Doussan1998-da
# Doussan2006-aj
# Draye2010-jd
# Drouet2003-hj
# Dusenge2019-jf
# Enstone2002-mh
# Evaristo2015-bq
# Farrar2000-ou
# Fiorani2013-id
# Frankenberg2011-om
# Garrigues2006-dq
# Godin1999-ag
# Heuvelink1996-ea
# Heymans2020-ln
# Heymans2021-nt
# Holbrook2018-wr
# Janott2011-zn
# Javaux2008-ur
# Jensen2012-hw
# Jensen2012-uy
# Ji2018-jq
# Jyske2015-kp
# Kallarackal2012-au
# Knoblauch2016-sr
# Knoblauch2016-zf
# Knoblauch2016-kj
# Knoblauch2017-oy
# Knoblauch2018-tg
# Kroeger2011-ki
# Lacointe2000-ee
# Lacointe2008-wu
# Lacointe2019-ar
# Lacointe2019-ec
# Landl2021-wf
# Leitner2010-xm
# Lichtenthaler1981-ui
# Lobet2012-ve
# Lobet2014-bf
# Lobet2013-nf
# Lobet2014-cq
# Lobet2014-jg
# Lockhart1965-gg
# Lopez2008-dt
# Lynch2013-ws
# Ma2018-dm
# Marcelis1996-yc
# Martinez-Vilalta2002-xe
# Martin-Vertedor2011-on
# Meunier2016-fp
# Minchin2017-bo
# Morandage2021-yx
# Morandage2021-xp
# Morandage2021-ac
# Muller2019-ld
# Muller2011-rc
# Munch1930-tb
# Pace1999-jn
# Page2011-of
# Pages2016-ul
# Pages2020-fu
# Pages2018-om
# Passot2016-uw
# Passot2018-qv
# Perkel2018-eu
# Peters2021-co
# Pincebourde2007-xk
# Pokhilko_Alexandra2015-yl
# Postma2017-iq
# Prusinkiewicz1988-eo
# Ramachandra_Reddy2004-nk
# Ray1972-sc
# Ryan1991-uq
# Savage2017-od
# Savage2017-gt
# Savage2016-ga
# Savage2013-fc
# Schlesinger2014-dm
# Schnepf2018-wa
# Schroder2008-jf
# Seleznyova2018-ng
# Sellin1993-bd
# Sharp2004-rh
# Sinoquet2001-dg
# Steppe2015-lg
# Steudle2001-mc
# Steudle1998-mu
# Stitt2010-gc
# Streb2012-no
# Tang2022-qm
# Thorpe2011-yn
# Tyree1997-eg
# Uys2021-at
# Van_Bel2003-ah
# Van_Veen1991-vk
# Vereecken2015-vc
# Vidal2020-sf
# De_Vries2021-vy
# Werner2002-kc
# William1991-jh
# Windt2006-fk
# Wullschleger2000-zn
# Yong_ZHANG2018-eo
# Zeng2017-de
# Zhou2020-ip
# Zhu2019-gp
# Zhu2010-di
# Zwieniecki2001-sb
# Zwieniecki2002-ek

# %%
len(used_references)
# Out:
# 129

# %%
used_references = set()
with open(aux_file, "r") as aux:
    for line in aux:

        if line.startswith("\\abx@aux@cite{0}{"):
            reference = line.strip().split("{")[2][:-1]
            used_references.add(reference)
            print(reference)
# Out:
# Dilkes2004-zi
# Dusenge2019-jf
# Bidel2000-db
# Jyske2015-kp
# Savage2016-ga
# Dilkes2004-zi
# Dusenge2019-jf
# Bar-On2018-ul
# Evaristo2015-bq
# Schlesinger2014-dm
# Beer2010-uj
# Frankenberg2011-om
# Vereecken2015-vc
# Dusenge2019-jf
# Van_Veen1991-vk
# Bar-On2018-ul
# Ryan1991-uq
# Evaristo2015-bq
# Schlesinger2014-dm
# Beer2010-uj
# Frankenberg2011-om
# Vereecken2015-vc
# Dusenge2019-jf
# Van_Veen1991-vk
# Bar-On2018-ul
# Ryan1991-uq
# Dilkes2004-zi
# Enstone2002-mh
# Farrar2000-ou
# Ji2018-jq
# Ramachandra_Reddy2004-nk
# Dusenge2019-jf
# Kroeger2011-ki
# Ray1972-sc
# Cosgrove2005-rv
# Cabon2020-vg
# Peters2021-co
# Pace1999-jn
# Daudet2005-eu
# Lockhart1965-gg
# Dusenge2019-jf
# Zeng2017-de
# Dusenge2019-jf
# Werner2002-kc
# Boardman1977-ai
# Lichtenthaler1981-ui
# Zhu2010-di
# Lobet2014-cq
# Lynch2013-ws
# Drouet2003-hj
# Lobet2014-cq
# De_Bauw2020-th
# Morandage2021-xp
# Morandage2021-yx
# Leitner2010-xm
# Sharp2004-rh
# Ahmed2022-te
# Bidel2000-nf
# Draye2010-jd
# Fiorani2013-id
# Lobet2013-nf
# Doussan1998-da
# Steudle1998-mu
# De_Vries2021-vy
# Uys2021-at
# Delory2016-gb
# Knoblauch2016-sr
# Jyske2015-kp
# Savage2016-ga
# Draye2010-jd
# Javaux2008-ur
# Lobet2014-cq
# Schroder2008-jf
# Bidel2000-nf
# De_Swaef2015-wc
# Savage2013-fc
# Van_Bel2003-ah
# Steudle2001-mc
# Tyree1997-eg
# Knoblauch2017-oy
# Munch1930-tb
# Comtet2017-ou
# Jensen2012-hw
# Knoblauch2016-sr
# Savage2017-od
# Prusinkiewicz1988-eo
# Godin1999-ag
# Drouet2003-hj
# Lobet2012-ve
# Seleznyova2018-ng
# Da_Silva2014-rb
# Barczi2008-gv
# Lacointe2000-ee
# Janott2011-zn
# Drouet2003-hj
# Janott2011-zn
# Lobet2012-ve
